# %% [markdown]
# # **Objective**

# %% [markdown]
# WAP to evaluate the performance of implemented three-layer neural network with variations in batch size and number of epochs.

# %% [markdown]
# # **Description of the Model:**

# %% [markdown]
# This is a three-layer neural network implemented using TensorFlow (without Keras) for classifying handwritten digits from the MNIST dataset.
#
# The model consists of:
#
# Input Layer (784 neurons): Accepts flattened 28x28 pixel images.
# Hidden Layer 1 (128 neurons): Uses ReLU activation to learn non-linear features.
# Hidden Layer 2 (64 neurons): Uses ReLU activation for deeper representation.
# Output Layer (10 neurons): Uses softmax activation to classify digits (0-9).
# Loss Function: Categorical cross-entropy.
# Optimizer: Adam Optimizer.
# Training: Mini-batch Gradient Descent with batch size = 64.

# %% [markdown]
# # **Python Implementation**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Disable eager execution
tf.compat.v1.disable_eager_execution()

# Load MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize and reshape input data
x_train, x_test = x_train / 255.0, x_test / 255.0
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# One-hot encoding for labels
y_train_onehot = np.eye(10)[y_train]
y_test_onehot = np.eye(10)[y_test]

# Define placeholders
X = tf.compat.v1.placeholder(tf.float32, [None, 784])
Y = tf.compat.v1.placeholder(tf.float32, [None, 10])

def init_weights(shape):
    return tf.Variable(tf.random.normal(shape, stddev=0.1))

# Initialize weights and biases
W1, b1 = init_weights([784, 128]), tf.Variable(tf.zeros([128]))
W2, b2 = init_weights([128, 64]), tf.Variable(tf.zeros([64]))
W3, b3 = init_weights([64, 10]), tf.Variable(tf.zeros([10]))

def forward_propagation(X):
    a1 = tf.nn.sigmoid(tf.matmul(X, W1) + b1)
    a2 = tf.nn.sigmoid(tf.matmul(a1, W2) + b2)
    return tf.matmul(a2, W3) + b3

logits = forward_propagation(X)
y_pred = tf.nn.softmax(logits)

# Loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))
optimizer = tf.compat.v1.train.AdamOptimizer().minimize(loss)

# Accuracy metric
correct_pred = tf.equal(tf.argmax(y_pred, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Training
batch_sizes = [100, 10, 1]
epochs_list = [100, 50, 10]

for batch_size in batch_sizes:
    for epochs in epochs_list:
        print(f"Training with batch size {batch_size} and epochs {epochs}")
        loss_history = []
        accuracy_history = []

        with tf.compat.v1.Session() as sess:
            sess.run(tf.compat.v1.global_variables_initializer())

            for epoch in range(epochs):
                epoch_loss, epoch_acc = 0, 0
                num_batches = x_train.shape[0] // batch_size

                for i in range(0, x_train.shape[0], batch_size):
                    batch_x, batch_y = x_train[i:i+batch_size], y_train_onehot[i:i+batch_size]
                    _, batch_loss, batch_acc = sess.run([optimizer, loss, accuracy], feed_dict={X: batch_x, Y: batch_y})
                    epoch_loss += batch_loss
                    epoch_acc += batch_acc

                epoch_loss /= num_batches
                epoch_acc = (epoch_acc / num_batches) * 100
                loss_history.append(epoch_loss)
                accuracy_history.append(epoch_acc)
                print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")

            # Evaluate on test set
            test_acc = sess.run(accuracy, feed_dict={X: x_test, Y: y_test_onehot}) * 100
            print(f"\nTest Accuracy: {test_acc:.2f}%")

            # Confusion matrix
            y_pred_labels = sess.run(tf.argmax(y_pred, 1), feed_dict={X: x_test})
            cm = confusion_matrix(y_test, y_pred_labels)

        # Plot loss curve
        plt.figure(figsize=(10, 4))
        plt.plot(range(1, epochs + 1), loss_history, marker='o', linestyle='-')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Loss Curve (Batch Size: {batch_size}, Epochs: {epochs}')
        plt.grid()
        plt.show()

        # Plot accuracy curve
        plt.figure(figsize=(10, 4))
        plt.plot(range(1, epochs + 1), accuracy_history, marker='o', linestyle='-')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy (%)')
        plt.title(f'Accuracy Curve (Batch Size: {batch_size}, Epochs: {epochs}')
        plt.grid()
        plt.show()

        # Plot confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
        plt.xlabel('Predicted Label')
        plt.ylabel('True Label')
        plt.title(f'Confusion Matrix (Batch Size: {batch_size}, Epochs: {epochs}')
        plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training with batch size 100 and epochs 100
# Epoch 1, Loss: 0.7677, Accuracy: 81.71%
# Epoch 2, Loss: 0.2610, Accuracy: 92.71%
# Epoch 3, Loss: 0.1902, Accuracy: 94.52%
# Epoch 4, Loss: 0.1493, Accuracy: 95.70%
# Epoch 5, Loss: 0.1214, Accuracy: 96.49%
# Epoch 6, Loss: 0.1010, Accuracy: 97.12%
# Epoch 7, Loss: 0.0854, Accuracy: 97.56%
# Epoch 8, Loss: 0.0730, Accuracy: 97.95%
# Epoch 9, Loss: 0.0629, Accuracy: 98.24%
# Epoch 10, Loss: 0.0543, Accuracy: 98.48%
# Epoch 11, Loss: 0.0469, Accuracy: 98.75%
# Epoch 12, Loss: 0.0403, Accuracy: 98.95%
# Epoch 13, Loss: 0.0345, Accuracy: 99.14%
# Epoch 14, Loss: 0.0293, Accuracy: 99.31%
# Epoch 15, Loss: 0.0247, Accuracy: 99.48%
# Epoch 16, Loss: 0.0207, Accuracy: 99.63%
# Epoch 17, Loss: 0.0173, Accuracy: 99.71%
# Epoch 18, Loss: 0.0143, Accuracy: 99.79%
# Epoch 19, Loss: 0.0117, Accuracy: 99.84%
# Epoch 20, Loss: 0.0095, Accuracy: 99.88%
# Epoch 21, Loss: 0.0076, Accuracy: 99.91%
# Epoch 22, Loss: 0.0060, Accuracy: 99.94%
# Epoch 23, Loss: 0.0047, Accuracy: 99.97%
# Epoch 24, Loss: 0.0037, Accuracy: 99.98%
# Epoch 25, Loss: 0.0029, Accuracy: 99.98%
# Epoch 26, Loss: 0.0022, Accuracy: 99.99%
# Epoch 27, Loss: 0.0016, Accuracy: 100.00%
# Epoch 28, Loss: 0.0013, Accuracy: 100.00%
# Epoch 29, Loss: 0.0010, Accuracy: 100.00%
# Epoch 30, Loss: 0.0013, Accuracy: 99.99%
# Epoch 31, Loss: 0.0086, Accuracy: 99.72%
# Epoch 32, Loss: 0.0014, Accuracy: 99.99%
# Epoch 33, Loss: 0.0007, Accuracy: 100.00%
# Epoch 34, Loss: 0.0005, Accuracy: 100.00%
# Epoch 35, Loss: 0.0004, Accuracy: 100.00%
# Epoch 36, Loss: 0.0003, Accuracy: 100.00%
# Epoch 37, Loss: 0.0003, Accuracy: 100.00%
# Epoch 38, Loss: 0.0002, Accuracy: 100.00%
# Epoch 39, Loss: 0.0002, Accuracy: 100.00%
# Epoch 40, Loss: 0.0002, Accuracy: 100.00%
# Epoch 25, Loss: 0.0105, Accuracy: 99.67%
# Epoch 26, Loss: 0.0089, Accuracy: 99.71%
# Epoch 27, Loss: 0.0104, Accuracy: 99.69%
# Epoch 28, Loss: 0.0112, Accuracy: 99.69%
# Epoch 29, Loss: 0.0093, Accuracy: 99.73%
# Epoch 30, Loss: 0.0109, Accuracy: 99.72%
# Epoch 31, Loss: 0.0089, Accuracy: 99.76%
# Epoch 32, Loss: 0.0096, Accuracy: 99.76%
# Epoch 33, Loss: 0.0090, Accuracy: 99.76%
# Epoch 34, Loss: 0.0093, Accuracy: 99.76%
# Epoch 35, Loss: 0.0078, Accuracy: 99.78%
# Epoch 36, Loss: 0.0096, Accuracy: 99.75%
# Epoch 37, Loss: 0.0074, Accuracy: 99.82%
# Epoch 38, Loss: 0.0075, Accuracy: 99.79%
# Epoch 39, Loss: 0.0085, Accuracy: 99.77%
# Epoch 40, Loss: 0.0072, Accuracy: 99.81%
# Epoch 41, Loss: 0.0081, Accuracy: 99.79%
# Epoch 42, Loss: 0.0071, Accuracy: 99.81%
# Epoch 43, Loss: 0.0078, Accuracy: 99.80%
# Epoch 44, Loss: 0.0069, Accuracy: 99.80%
# Epoch 45, Loss: 0.0068, Accuracy: 99.81%
# Epoch 46, Loss: 0.0071, Accuracy: 99.83%
# Epoch 47, Loss: 0.0079, Accuracy: 99.82%
# Epoch 48, Loss: 0.0060, Accuracy: 99.83%
# Epoch 49, Loss: 0.0075, Accuracy: 99.82%
# Epoch 50, Loss: 0.0065, Accuracy: 99.82%
#
# Test Accuracy: 97.41%
# Training with batch size 1 and epochs 10
# Epoch 1, Loss: 0.2287, Accuracy: 93.43%
# Epoch 2, Loss: 0.0997, Accuracy: 97.07%
# Epoch 3, Loss: 0.0705, Accuracy: 97.93%
# Epoch 4, Loss: 0.0560, Accuracy: 98.33%
# Epoch 5, Loss: 0.0445, Accuracy: 98.68%
# Epoch 6, Loss: 0.0369, Accuracy: 98.91%
# Epoch 7, Loss: 0.0302, Accuracy: 99.05%
# Epoch 8, Loss: 0.0276, Accuracy: 99.17%
# Epoch 9, Loss: 0.0248, Accuracy: 99.24%
# Epoch 10, Loss: 0.0208, Accuracy: 99.34%
#
# Test Accuracy: 97.34%

# %% [markdown]
# # **Description of the Code Preprocessing:**
#  Images are flattened (28×28 → 784) and normalized (0-255 → 0-1). Labels are one-hot encoded.
#
# Neural Network Architecture:
#
# Input layer: 784 neurons (flattened image)
#
# Hidden Layer 1: 128 neurons (sigmoid activation)
#
# Hidden Layer 2: 64 neurons (sigmoid activation)
#
# Output Layer: 10 neurons (softmax for classification)
#
# Training Process:
#
# Loss Function: Softmax Cross-Entropy
# Optimizer: Gradient Descent
# The model is trained using mini-batch gradient descent
# Performance Tracking: Loss and Accuracy are recorded and plotted.

# %% [markdown]
# # **My Comments:**
#
#
#
# *   TensorFlow 1.x Deprecation: The code uses TensorFlow 1.x, which is outdated. Consider updating it to TensorFlow 2.x for better performance and maintainability.
# *   activation function : the code uses sigmoid function , updating it to relu will give better execution.
