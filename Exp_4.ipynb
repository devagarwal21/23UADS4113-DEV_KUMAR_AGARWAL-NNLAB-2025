# %% [markdown]
# # **Objective**

# %% [markdown]
# WAP to evaluate the performance of implemented three-layer neural network with variations in batch size and number of epochs.

# %% [markdown]
# # **Description of the Model:**

# %% [markdown]
# This is a three-layer neural network implemented using TensorFlow (without Keras) for classifying handwritten digits from the MNIST dataset.
#
# The model consists of:
#
# Input Layer (784 neurons): Accepts flattened 28x28 pixel images.
# Hidden Layer 1 (128 neurons): Uses ReLU activation to learn non-linear features.
# Hidden Layer 2 (64 neurons): Uses ReLU activation for deeper representation.
# Output Layer (10 neurons): Uses softmax activation to classify digits (0-9).
# Loss Function: Categorical cross-entropy.
# Optimizer: Adam Optimizer.
# Training: Mini-batch Gradient Descent with batch size = 64.

# %% [markdown]
# # **Python Implementation**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Disable eager execution
tf.compat.v1.disable_eager_execution()

# Load MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize and reshape input data
x_train, x_test = x_train / 255.0, x_test / 255.0
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# One-hot encoding for labels
y_train_onehot = np.eye(10)[y_train]
y_test_onehot = np.eye(10)[y_test]

# Define placeholders
X = tf.compat.v1.placeholder(tf.float32, [None, 784])
Y = tf.compat.v1.placeholder(tf.float32, [None, 10])

def init_weights(shape):
    return tf.Variable(tf.random.normal(shape, stddev=0.1))

# Initialize weights and biases
W1, b1 = init_weights([784, 128]), tf.Variable(tf.zeros([128]))
W2, b2 = init_weights([128, 64]), tf.Variable(tf.zeros([64]))
W3, b3 = init_weights([64, 10]), tf.Variable(tf.zeros([10]))

def forward_propagation(X):
    a1 = tf.nn.sigmoid(tf.matmul(X, W1) + b1)
    a2 = tf.nn.sigmoid(tf.matmul(a1, W2) + b2)
    return tf.matmul(a2, W3) + b3

logits = forward_propagation(X)
y_pred = tf.nn.softmax(logits)

# Loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))
optimizer = tf.compat.v1.train.AdamOptimizer().minimize(loss)

# Accuracy metric
correct_pred = tf.equal(tf.argmax(y_pred, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Training
batch_sizes = [100, 10, 1]
epochs_list = [100, 50, 10]

for batch_size in batch_sizes:
    for epochs in epochs_list:
        print(f"Training with batch size {batch_size} and epochs {epochs}")
        loss_history = []
        accuracy_history = []

        with tf.compat.v1.Session() as sess:
            sess.run(tf.compat.v1.global_variables_initializer())

            for epoch in range(epochs):
                epoch_loss, epoch_acc = 0, 0
                num_batches = x_train.shape[0] // batch_size

                for i in range(0, x_train.shape[0], batch_size):
                    batch_x, batch_y = x_train[i:i+batch_size], y_train_onehot[i:i+batch_size]
                    _, batch_loss, batch_acc = sess.run([optimizer, loss, accuracy], feed_dict={X: batch_x, Y: batch_y})
                    epoch_loss += batch_loss
                    epoch_acc += batch_acc

                epoch_loss /= num_batches
                epoch_acc = (epoch_acc / num_batches) * 100
                loss_history.append(epoch_loss)
                accuracy_history.append(epoch_acc)
                print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")

            # Evaluate on test set
            test_acc = sess.run(accuracy, feed_dict={X: x_test, Y: y_test_onehot}) * 100
            print(f"\nTest Accuracy: {test_acc:.2f}%")

            # Confusion matrix
            y_pred_labels = sess.run(tf.argmax(y_pred, 1), feed_dict={X: x_test})
            cm = confusion_matrix(y_test, y_pred_labels)

        # Plot loss curve
        plt.figure(figsize=(10, 4))
        plt.plot(range(1, epochs + 1), loss_history, marker='o', linestyle='-')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Loss Curve (Batch Size: {batch_size}, Epochs: {epochs}')
        plt.grid()
        plt.show()

        # Plot accuracy curve
        plt.figure(figsize=(10, 4))
        plt.plot(range(1, epochs + 1), accuracy_history, marker='o', linestyle='-')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy (%)')
        plt.title(f'Accuracy Curve (Batch Size: {batch_size}, Epochs: {epochs}')
        plt.grid()
        plt.show()

        # Plot confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
        plt.xlabel('Predicted Label')
        plt.ylabel('True Label')
        plt.title(f'Confusion Matrix (Batch Size: {batch_size}, Epochs: {epochs}')
        plt.show()
# Out:
# Training with batch size 100 and epochs 100
# Epoch 1, Loss: 0.7861, Accuracy: 81.48%
# Epoch 2, Loss: 0.2638, Accuracy: 92.62%
# Epoch 3, Loss: 0.1926, Accuracy: 94.55%
# Epoch 4, Loss: 0.1518, Accuracy: 95.58%
# Epoch 5, Loss: 0.1240, Accuracy: 96.49%
# Epoch 6, Loss: 0.1033, Accuracy: 97.09%
# Epoch 7, Loss: 0.0873, Accuracy: 97.53%
# Epoch 8, Loss: 0.0743, Accuracy: 97.91%
# Epoch 9, Loss: 0.0635, Accuracy: 98.26%
# Epoch 10, Loss: 0.0544, Accuracy: 98.50%
# Epoch 11, Loss: 0.0466, Accuracy: 98.74%
# Epoch 12, Loss: 0.0398, Accuracy: 98.99%
# Epoch 13, Loss: 0.0339, Accuracy: 99.18%
# Epoch 14, Loss: 0.0287, Accuracy: 99.34%
# Epoch 15, Loss: 0.0243, Accuracy: 99.49%
# Epoch 16, Loss: 0.0204, Accuracy: 99.61%
# Epoch 17, Loss: 0.0169, Accuracy: 99.70%
# Epoch 18, Loss: 0.0140, Accuracy: 99.78%
# Epoch 19, Loss: 0.0115, Accuracy: 99.84%
# Epoch 20, Loss: 0.0093, Accuracy: 99.89%
# Epoch 21, Loss: 0.0075, Accuracy: 99.92%
# Epoch 22, Loss: 0.0059, Accuracy: 99.94%
# Epoch 23, Loss: 0.0046, Accuracy: 99.96%
# Epoch 24, Loss: 0.0035, Accuracy: 99.98%
# Epoch 25, Loss: 0.0027, Accuracy: 99.99%
# Epoch 26, Loss: 0.0021, Accuracy: 99.99%
# Epoch 27, Loss: 0.0016, Accuracy: 100.00%
# Epoch 28, Loss: 0.0012, Accuracy: 100.00%
# Epoch 29, Loss: 0.0009, Accuracy: 100.00%
# Epoch 30, Loss: 0.0007, Accuracy: 100.00%
# Epoch 31, Loss: 0.0005, Accuracy: 100.00%
# Epoch 32, Loss: 0.0004, Accuracy: 100.00%
# Epoch 33, Loss: 0.0003, Accuracy: 100.00%
# Epoch 34, Loss: 0.0002, Accuracy: 100.00%
# Epoch 2, Loss: 0.1001, Accuracy: 97.07%
# Epoch 3, Loss: 0.0717, Accuracy: 97.93%
# Epoch 4, Loss: 0.0546, Accuracy: 98.40%
# Epoch 5, Loss: 0.0449, Accuracy: 98.66%
# Epoch 6, Loss: 0.0372, Accuracy: 98.89%
# Epoch 7, Loss: 0.0314, Accuracy: 99.06%
# Epoch 8, Loss: 0.0283, Accuracy: 99.10%
# Epoch 9, Loss: 0.0239, Accuracy: 99.24%
# Epoch 10, Loss: 0.0231, Accuracy: 99.27%
# Epoch 11, Loss: 0.0182, Accuracy: 99.42%
# Epoch 12, Loss: 0.0169, Accuracy: 99.44%
# Epoch 13, Loss: 0.0175, Accuracy: 99.45%
# Epoch 14, Loss: 0.0157, Accuracy: 99.50%
# Epoch 15, Loss: 0.0140, Accuracy: 99.57%
# Epoch 16, Loss: 0.0132, Accuracy: 99.59%
# Epoch 17, Loss: 0.0144, Accuracy: 99.58%
# Epoch 18, Loss: 0.0130, Accuracy: 99.62%
# Epoch 19, Loss: 0.0129, Accuracy: 99.61%
# Epoch 20, Loss: 0.0119, Accuracy: 99.64%
# Epoch 21, Loss: 0.0108, Accuracy: 99.68%
# Epoch 22, Loss: 0.0106, Accuracy: 99.67%
# Epoch 23, Loss: 0.0133, Accuracy: 99.66%
# Epoch 26, Loss: 0.0102, Accuracy: 99.69%
# Epoch 27, Loss: 0.0111, Accuracy: 99.67%
# Epoch 28, Loss: 0.0092, Accuracy: 99.74%
# Epoch 29, Loss: 0.0087, Accuracy: 99.77%
# Epoch 30, Loss: 0.0081, Accuracy: 99.77%
# Epoch 31, Loss: 0.0072, Accuracy: 99.80%
# Epoch 32, Loss: 0.0098, Accuracy: 99.75%
# Epoch 33, Loss: 0.0074, Accuracy: 99.78%
# Epoch 34, Loss: 0.0082, Accuracy: 99.78%
# Epoch 36, Loss: 0.0075, Accuracy: 99.78%
# Epoch 37, Loss: 0.0066, Accuracy: 99.81%
# Epoch 38, Loss: 0.0068, Accuracy: 99.81%
# Epoch 39, Loss: 0.0065, Accuracy: 99.83%
# Epoch 40, Loss: 0.0087, Accuracy: 99.78%
# Epoch 41, Loss: 0.0057, Accuracy: 99.82%
# Epoch 42, Loss: 0.0065, Accuracy: 99.84%

# %% [markdown]
# # **Description of the Code Preprocessing:**
#  Images are flattened (28×28 → 784) and normalized (0-255 → 0-1). Labels are one-hot encoded.
#
# Neural Network Architecture:
#
# Input layer: 784 neurons (flattened image)
#
# Hidden Layer 1: 128 neurons (sigmoid activation)
#
# Hidden Layer 2: 64 neurons (sigmoid activation)
#
# Output Layer: 10 neurons (softmax for classification)
#
# Training Process:
#
# Batch Size: 64
# Epochs: 10
# Loss Function: Softmax Cross-Entropy
# Optimizer: Gradient Descent
# The model is trained using mini-batch gradient descent
# Performance Tracking: Loss and Accuracy are recorded and plotted.

# %% [markdown]
# # **My Comments:**
